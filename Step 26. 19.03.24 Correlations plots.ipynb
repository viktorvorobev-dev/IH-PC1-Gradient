# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('Patients index + BLB.xlsx', header = 1)
df.head()
# Out:
#   Patient Initials  Age (months) Locality  Size (cm)  Score  \
# 0    3501     К Е.           6.0     Face      0.035      4
# 1    3434     Д В.           5.0     Side      3.000      2
# 2    3503    Ч А.           10.0    Groin      7.500     13
# 3    3504     А И.           9.0     Back      1.000      2
# 4    3505     А Р.           7.0    Chest      4.000      3
#
#   Treatment tacktics   Score with age contribution  Hemangioma mean   \
# 0  Local Conservative                            7        169.771064
# 1  Local Conservative                            5        173.620880
# 2           Operation                           15        204.714842
# 3         Observation                            4        142.344354
# 4  Local Conservative                            6        190.953770
#
#    Hemangioma std   ...  Hemangioma std / Hemangioma mean  \
# 0        40.626728  ...                          0.239303
# 1        32.187894  ...                          0.185392
# 2        27.385164  ...                          0.133772
# 3        36.782518  ...                          0.258405
# 4        27.901895  ...                          0.146119
#
#    BLB Hemangioma mean   BLB Hemangioma std   BLB Skin mean  BLB Skin std  \
# 0             28.488550            13.668805       3.874805      1.735078
# 1             81.829271            25.413705      27.048685      9.934771
# 2            181.896710            44.032560      14.662424     17.952333
# 3             23.621320             7.335172       7.349662      3.212261
# 4            196.383877            46.557159      10.926120     17.793928
#
#    BLB Hemangioma area  BLB Slope  BLB Hemangioma / Skin mean  \
# 0               8341.0   0.947847                    7.352254
# 1             467472.5   0.029044                    3.025259
# 2             324834.0   0.045468                   12.405637
# 3             218803.0   0.033239                    3.213933
# 4             565287.0   0.045470                   17.973798
#
#    BLB Hemangioma std / Hemangioma mean  1 / sqrt(Hemangioma area)
# 0                              0.479800                   0.007817
# 1                              0.310570                   0.001214
# 2                              0.242075                   0.000887
# 3                              0.310532                   0.001676
# 4                              0.237072                   0.000861
#
# [5 rows x 25 columns]

# %% [markdown]
# # Calculations

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="Hemangioma area", data=df, alpha = 0.5)
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="BLB Hemangioma area", data=df, alpha = 0.5)
plt.show()
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Score", y="Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.xlim(1.5,7.5)
plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Score", y="BLB Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.xlim(1.5,7.5)
plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Score with age contribution", y="Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Score with age contribution", y="BLB Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Treatment tacktics ", y="Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
plt.xticks(rotation = 30)
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Treatment tacktics ", y="BLB Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
plt.xticks(rotation = 30)
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Treatment tacktics ", y="BLB Slope", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
plt.xticks(rotation = 30)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Local Conservative'),
#   Text(1, 0, 'Operation'),
#   Text(2, 0, 'Observation')])

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Score", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Score", y="BLB Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Score with age contribution", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Score with age contribution", y="BLB Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-0.,1.5)
# plt.xlim(1.5, 7.5)
# plt.legend()
# Out:
# (-0.0, 1.5)

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="BLB Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,1.5)
plt.xlim(0,8)
# plt.legend()
# Out:
# (0.0, 8.0)

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Hemangioma area", y="Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
plt.xlim(0,2.5e6)
plt.show()


plt.figure(dpi = 150)
sns.scatterplot(x="BLB Hemangioma area", y="BLB Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,1.5)
# plt.xlim(0,2.5e6)
plt.show()


plt.figure(dpi = 150)
sns.scatterplot(x="Hemangioma area", y="BLB Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,1.5)
# plt.xlim(0,2.5e6)
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(y="Slope", x="Hemangioma / Skin mean", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
# plt.xticks(rotation = 30)
plt.ylim(0,0.09)
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(y="BLB Slope", x="BLB Hemangioma / Skin mean", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
# plt.xticks(rotation = 30)
plt.ylim(0,1.5)
plt.show()

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'BLB Slope', hue = 'Treatment tacktics ', element="step", kde = True, kde_kws = {'bw_adjust': 0.25})
plt.xlim(0,1.5)
# Out:
# (0.0, 1.5)

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'BLB Hemangioma / Skin mean', hue = 'Treatment tacktics ', element="step", kde = True, kde_kws = {'bw_adjust': 0.25})
# plt.xlim(0,0.09)
# Out:
# <Axes: xlabel='BLB Hemangioma / Skin mean', ylabel='Count'>

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'Score with age contribution', hue = 'Treatment tacktics ', element="step", kde = False, kde_kws = {'bw_adjust': 0.25})
# plt.xlim(0,0.09)
# Out:
# <Axes: xlabel='Score with age contribution', ylabel='Count'>

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'Score', hue = 'Treatment tacktics ', element="step", kde = False, kde_kws = {'bw_adjust': 0.25})
# plt.xlim(0,0.09)
# Out:
# <Axes: xlabel='Score', ylabel='Count'>

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="1 / sqrt(Hemangioma area)", y="Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0.004,0.1)
plt.xlim(6e-4, 4e-3)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$1/\sqrt{Area_{Hemangioma}}$')
plt.show()
