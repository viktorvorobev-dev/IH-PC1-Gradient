# %%
import Computational_v3_single_visit_dict as Computational
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
amount_of_components = 4
names = ['3637',
'3477',
'3561',
]
PCA_result = Computational.PCA_ICA(names = names, number_of_components = amount_of_components, if_use_ICA = False)
# Out:
# Explained_variance_ratio_by_each_component =  [0.80384512 0.08855254 0.04316393 0.0228218 ]
# Explained_variance_ratio =  0.9583833989180629
# Explained_variance_ratio_by_each_component =  [0.62088877 0.19436794 0.05595931 0.04181375]
# Explained_variance_ratio =  0.9130297672180442
# Explained_variance_ratio_by_each_component =  [0.87912297 0.07656636 0.01762678 0.00954475]
# Explained_variance_ratio =  0.9828608750004129

# %%
result_mean, result_std = Computational.analysis_of_distributions(dictionary_of_visits = PCA_result, 
                                                                           names = names, which_component_to_use = 0, 
                                                                           gaussian_blur = 2)

# %%
print('hemangioma mean')
for i in range(len(names)):
    print(list(result_mean['hemangioma'].values())[i])
# Out:
# hemangioma mean
# 206.51152642707223
# 140.55577717095383
# 180.66160235841798

# %%
print('hemangioma std')
for i in range(len(names)):
    print(list(result_std['hemangioma'].values())[i])
# Out:
# hemangioma std
# 23.61686231149018
# 34.123772035538515
# 35.25738461312996

# %%
print('skin mean')
for i in range(len(names)):
    print(list(result_mean['skin'].values())[i])
# Out:
# skin mean
# 95.15683991513917
# 67.81091685781742
# 60.367732697502134

# %%
print('skin std')
for i in range(len(names)):
    print(list(result_std['skin'].values())[i])
# Out:
# skin std
# 24.996527036237772
# 19.434457750401023
# 31.65571633950963

# %%
mean = {} 
std = {} 
area = {}
length = {}
thresholds = {}
skin = {}
for i in range(len(names)):
    print(i)
    mean[i], std[i], area[i], length[i] = Computational.Borders_values(dictionary_of_visits = PCA_result,                     
                                    name = names[i], 
                                    which_component_to_use = 0,
                                    gaussian_blur = 2, 
                                    step = 1)
    
    
    skin[i] = Computational.extract_skin_value(dictionary_of_visits = PCA_result, 
                                    name = names[i], 
                                    which_component_to_use = 0,
                                    gaussian_blur = 2)
# Out:
# 0
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [15:35<00:00,  9.64s/it]
# 1
# 100%|██████████████████████████████████████████████████████████████████████████████| 157/157 [1:40:01<00:00, 38.23s/it]
# 2
# 100%|██████████████████████████████████████████████████████████████████████████████| 138/138 [1:29:19<00:00, 38.84s/it]

# %%
print('Mean Slope')
for i in range(len(names)):
    print(-np.mean(np.diff(mean[i]/skin[i]) / np.diff(np.sqrt(np.array(area[i])/4/np.pi))))
# Out:
# Mean Slope
# 0.011000683310436988
# 0.010355213630157721
# 0.00838995973152958

# %%
print('Hemangioma Area')
for i in range(len(names)):
    print((area[i])[0])
# Out:
# Hemangioma Area
# 458178.0
# 809500.0
# 951918.5
