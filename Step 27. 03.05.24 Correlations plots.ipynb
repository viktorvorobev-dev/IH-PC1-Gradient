# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('Patients index edited.xlsx', header = 1)
df.head()
# Out:
#   Patient Initials  Age (months) Locality  Size (cm)  HSS Score  HAS Score  \
# 0    3501     К Е.           6.0     Face      0.035          4        3.0
# 1    3434     Д В.           5.0     Side      3.000          2        3.0
# 2    3503    Ч А.           10.0    Groin      7.500         13        2.5
# 3    3504     А И.           9.0     Back      1.000          2        3.0
# 4    3505     А Р.           7.0    Chest      4.000          3        3.0
#
#    HASI Score  HASI Color  HASI Grey Regress  ... Hemangioma mean   \
# 0         6.0         6.0                NaN  ...       169.771064
# 1         6.0         6.0               -1.0  ...       173.620880
# 2        16.0         7.0                NaN  ...       204.714842
# 3         4.0         6.0               -2.0  ...       142.344354
# 4         8.0         6.0                NaN  ...       190.953770
#
#    Hemangioma std   Skin mean   Skin std  Hemangioma area     Slope  \
# 0        40.626728  36.965428  13.036847          16366.0  0.155758
# 1        32.187894  63.769886  23.062573         678680.0  0.009163
# 2        27.385164  47.134445  28.707296        1271838.5  0.011986
# 3        36.782518  54.158892  17.335332         355931.5  0.014598
# 4        27.901895  42.026359  25.990098        1349488.5  0.014331
#
#    Hemangioma / Skin mean  Hemangioma std / Hemangioma mean  \
# 0                4.592698                          0.239303
# 1                2.722616                          0.185392
# 2                4.343211                          0.133772
# 3                2.628273                          0.258405
# 4                4.543667                          0.146119
#
#    1 / sqrt(Hemangioma area)   1 / Size (cm)
# 0                   0.007817       28.571429
# 1                   0.001214        0.333333
# 2                   0.000887        0.133333
# 3                   0.001676        1.000000
# 4                   0.000861        0.250000
#
# [5 rows x 21 columns]

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="HSS Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="HAS Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="HASI Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="HASI Grey Regress", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HAS Score", y="HSS Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
# plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(y="HASI Score", x="HSS Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
# plt.xlim(0,8)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(y="HASI Score", x="HAS Score", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
# plt.xlim(0,8)
# plt.legend()
plt.show()

# %% [markdown]
# # Calculations

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="Hemangioma area", data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
# Out:
# <Axes: xlabel='Size (cm)', ylabel='Hemangioma area'>

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HSS Score", y="Hemangioma / Skin mean", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HAS Score", y="Hemangioma / Skin mean", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HASI Score", y="Hemangioma / Skin mean", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend(fontsize = 'small')

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HASI Color", y="Hemangioma / Skin mean", data=df, alpha = 0.5, label = 'Score')
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()
plt.show()


plt.figure(dpi = 150)
sns.scatterplot(x="HASI Grey Regress", y="Hemangioma / Skin mean", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(1.5,7.5)
plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HSS Score", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()


plt.figure(dpi = 150)
sns.scatterplot(x="HAS Score", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="HASI Score", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="HASI Color", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

plt.figure(dpi = 150)
sns.scatterplot(x="HASI Grey Regress", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HASI Score", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
# plt.xlim(1.5, 7.5)
# plt.legend()
plt.yscale('log')
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Size (cm)", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.1)
plt.xlim(0,8)
# plt.legend()
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x=" 1 / Size (cm)", y="Slope", data=df, hue = 'Treatment tacktics ', alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
# plt.xlim(0,3)
# plt.legend()
plt.yscale('log')
plt.xscale('log')
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="Hemangioma area", y="Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.09)
plt.xlim(0,2.5e6)
# Out:
# (0.0, 2500000.0)

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="HASI Score", y="Hemangioma std / Hemangioma mean", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
# plt.xlim(0,2.5e6)
plt.show()

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="1 / sqrt(Hemangioma area)", y="Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
plt.xlim(0.0005,0.0035)
plt.yscale('log')
plt.xscale('log')

# %%
plt.figure(dpi = 150)
sns.scatterplot(y="Slope", x="Hemangioma / Skin mean", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
# plt.xticks(rotation = 30)
plt.ylim(0,0.09)
# Out:
# (0.0, 0.09)

# %%
plt.figure(dpi = 150)
sns.scatterplot(y="Slope", x="Hemangioma / Skin mean", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.xlim(0,20)
# plt.xticks(rotation = 30)
# plt.ylim(0,0.09)
plt.yscale('log')
# plt.xscale('log')

# %%
plt.figure(dpi = 150)
sns.scatterplot(x="1/Hemangioma area", y="Slope", hue = 'Treatment tacktics ', data=df, alpha = 0.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.09)
# plt.xlim(0,2.5e6)

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'Slope', hue = 'Treatment tacktics ', element="step", kde = True, kde_kws = {'bw_adjust': 0.25})
plt.xlim(0,0.09)
# Out:
# (0.0, 0.09)

# %%
plt.figure(dpi = 150)
sns.histplot(df, x = 'Hemangioma / Skin mean', hue = 'Treatment tacktics ', element="step", kde = True, kde_kws = {'bw_adjust': 0.25})
# plt.xlim(0,0.09)
# Out:
# <Axes: xlabel='Hemangioma / Skin mean', ylabel='Count'>
