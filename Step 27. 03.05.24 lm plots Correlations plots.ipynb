# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt
import scipy as sp

# %%
df = pd.read_excel('Patients index edited for lmplots.xlsx', header = 1)
df.head()
# Out:
#   Patient Initials  Age (months) Locality  Size (cm)  HSS Score  HAS Score  \
# 0    3501     К Е.           6.0     Face      0.035          4        3.0
# 1    3434     Д В.           5.0     Side      3.000          2        3.0
# 2    3503    Ч А.           10.0    Groin      7.500         13        2.5
# 3    3504     А И.           9.0     Back      1.000          2        3.0
# 4    3505     А Р.           7.0    Chest      4.000          3        3.0
#
#    HASI Score  HASI Color  HASI Grey Regress  ... Hemangioma / Skin mean  \
# 0         6.0         6.0                NaN  ...               4.592698
# 1         6.0         6.0               -1.0  ...               2.722616
# 2        16.0         7.0                NaN  ...               4.343211
# 3         4.0         6.0               -2.0  ...               2.628273
# 4         8.0         6.0                NaN  ...               4.543667
#
#    Hemangioma std / Hemangioma mean  1 / sqrt(Hemangioma area)  \
# ...

# %% [markdown]
# # Calculations

# %%
plt.figure(dpi = 150)
x="Size (cm)"
y="sqrt(Hemangioma area)"
sns.regplot(x = x, y = y, data=df, robust=True)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.5684122717902824
# p =  2.07860765193455e-08

# %%
plt.figure(dpi = 150)
x="Size (cm)"
y="Hemangioma area"
sns.regplot(x = x, y = y, data=df, robust=True)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.506990474689688
# p =  1.0033613668544712e-06

# %%
plt.figure(dpi = 150)
x="HAS Score"
y="Hemangioma / Skin mean"
hue = 'Treatment tacktics '
sns.regplot(x = x, y = y, data=df, robust=True)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

plt.figure(dpi = 150)
x="HAS Score"
y="Hemangioma / Skin mean"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('\np = ', p)
# Out:
# r =  0.38748716614010414
#
# p =  0.0003224439073339045

# %%
plt.figure(dpi = 150)
x="HSS Score"
y="Hemangioma / Skin mean"
hue = 'Treatment tacktics '
sns.regplot(x = x, y = y, data=df, robust=True)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

plt.figure(dpi = 150)
x="HSS Score"
y="Hemangioma / Skin mean"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.16)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('\np = ', p)
# Out:
# r =  0.07676691084894609
#
# p =  0.49032487807266417

# %%
plt.figure(dpi = 150)
x="HASI Score"
y="Slope"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(0,0.1)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.035621871612575934
# p =  0.7615779513899035

# %%
plt.figure(dpi = 150)
x="HAS Score"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,20)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(0,0.1)
# plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
plt.figure(dpi = 150)
x="log10( 1 / Size (cm))"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df['Slope'])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.5935544134136986
# p =  2.496865642522522e-08

# %%
plt.figure(dpi = 150)
x="HASI Score"
y="Hemangioma std "
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  -0.008871684127495266
# p =  0.9373462797481541

# %%
plt.figure(dpi = 150)
x="log10(1 / sqrt(Hemangioma area))"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.25)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
# { “scatter” | “kde” | “hist” | “hex” | “reg” | “resid” }
sns.jointplot(
    x = x, y = y, data=df, hue = hue,
    kind='scatter'
)
plt.xlim(-7.5,-4.5)
plt.ylim(-2.5, 0)
# Out:
# (-2.5, 0.0)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.7455810947568673
# p =  2.5369846524887157e-14

# %%
plt.figure(dpi = 150)
x="log10(1 / sqrt(Hemangioma area))"
y="Slope"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-.0,0.2)
# # # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.33268200575287094
# p =  0.0031143130147494283

# %%
plt.figure(dpi = 150)
x="1 / sqrt(Hemangioma area)"
y="Slope"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-.0,0.2)
# # # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.33314002214107086
# p =  0.003070976260277427

# %%
plt.figure(dpi = 150)
x="Hemangioma / Skin mean"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.25)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])

sns.set_style('whitegrid', {'axes.linewidth': 2, 'axes.edgecolor':'black'})
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  0.6622868173083981
# p =  1.308107121229651e-10

# %%
sns.jointplot(
    x = x, y = y, data=df, hue = hue,
    kind='scatter'
)
plt.xlim(1.,6)
plt.ylim(-2.5, 0)
# Out:
# (-2.5, 0.0)

# %%
plt.figure(dpi = 150)
x="Hemangioma area"
y="Slope"
hue = 'Treatment tacktics '
sns.lmplot(x = x, y = y, data=df, hue = hue, aspect = 1.5)
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
# plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
df_new = pd.DataFrame({x: df[x], y: df[y]})
df_new.dropna(inplace=True)
r, p = sp.stats.pearsonr(df_new[x], df_new[y])

print('r = ', r)
print('p = ', p)
# Out:
# r =  -0.2574363545690277
# p =  0.023803387322610284

# %%
sns.jointplot(
    x = x, y = y, data=df, hue = hue,
    kind='scatter'
)
plt.xlim(-0.1e6,3e6)
plt.ylim(0, 0.2)
# Out:
# (0.0, 0.2)

# %%
plt.figure(dpi = 150)
x="log10(1 / sqrt(Hemangioma area))"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.relplot(x = x, y = y, data=df, hue = hue, aspect = 1.5, size = 'HAS Score')
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)

# %%
plt.figure(dpi = 150)
x="Hemangioma / Skin mean"
y="log10(Slope)"
hue = 'Treatment tacktics '
sns.relplot(x = x, y = y, data=df, hue = hue, aspect = 1.5, size = 'Size (cm)')
# plt.xlim(0,2.5)
# sns.scatterplot(y="Hemangioma / Skin mean", x="Score with age contribution", data=df, alpha = 0.5, label = 'Score with age')
plt.ylim(-2.5,0)
# # plt.legend()
# r, p = sp.stats.pearsonr(df[x], df[y])
plt.show()

# print('r = ', r)
# print('p = ', p)
